# %%
import window_make
import Ridge
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %% [markdown]
# # Read Data

# %%
PATH_NAME_CO2 = 'archive.csv'
train = pd.read_csv(PATH_NAME_CO2, encoding='CP949')

# %%
train
# Out:
#      Year  Month  Decimal Date  Carbon Dioxide (ppm)  \
# 0    1958      1     1958.0411                   NaN
# 1    1958      2     1958.1260                   NaN
# 2    1958      3     1958.2027                315.69
# 3    1958      4     1958.2877                317.45
# 4    1958      5     1958.3699                317.50
# ..    ...    ...           ...                   ...
# 715  2017      8     2017.6219                   NaN
# 716  2017      9     2017.7068                   NaN
# 717  2017     10     2017.7890                   NaN
# 718  2017     11     2017.8740                   NaN
# 719  2017     12     2017.9562                   NaN
#
#      Seasonally Adjusted CO2 (ppm)  Carbon Dioxide Fit (ppm)  \
# 0                              NaN                       NaN
# 1                              NaN                       NaN
# 2                           314.42                    316.18
# 3                           315.15                    317.30
# 4                           314.73                    317.83
# ..                             ...                       ...
# 715                            NaN                       NaN
# 716                            NaN                       NaN
# 717                            NaN                       NaN
# 718                            NaN                       NaN
# 719                            NaN                       NaN
#
#      Seasonally Adjusted CO2 Fit (ppm)
# 0                                  NaN
# 1                                  NaN
# 2                               314.89
# 3                               314.98
# 4                               315.06
# ..                                 ...
# 715                                NaN
# 716                                NaN
# 717                                NaN
# 718                                NaN
# 719                                NaN
#
# [720 rows x 7 columns]

# %%
train = train.to_numpy()

# %%
print("Total data shape is", train.shape)
print("The number of sample is ",len(train[0]))
co2 = train[:,3]
# Out:
# Total data shape is (720, 7)
# The number of sample is  7

# %% [markdown]
# ### Data visualization

# %%
plt.plot(co2)
plt.ylabel('co2(ppm)')
plt.xlabel('time series')
# Out:
# Text(0.5, 0, 'time series')

# %% [markdown]
# # Window sliding

# %%
X_i,Y_i = window_make.dowlist(co2,7)

# %%
print("The number of sample widows are", X_i.shape[0])
print("Window size is", X_i.shape[1])
# Out:
# The number of sample widows are 683
# Window size is 7

# %% [markdown]
# # Ridge regression

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from scipy import stats
import statistics


# divide test data and train data
X_train, X_test, Y_train, Y_test = train_test_split(X_i, Y_i, test_size=0.2, random_state=1)

# training
X_norm = stats.zscore(X_train,axis=0)
X_std = np.std(X_train,axis=0)
X_mean = np.mean(X_train,axis=0)

beta_ridge, beta_0 = Ridge.solve(X_norm, Y_train,0.1)

# %%
# test
test_norm = (X_test-X_mean)/X_std
Y_pred = np.matmul(test_norm, beta_ridge)+beta_0

mse = mean_squared_error(Y_test, Y_pred)
print("Result MSE, RMSE ",mse, np.sqrt(mse))
# Out:
# Result MSE, RMSE  0.5402609281251806 0.7350244404951312

# %%
print("beta_ridge : ",beta_ridge)
# Out:
# beta_ridge :  [[ 6.44253389]
#  [-6.3787029 ]
#  [ 3.28293688]
#  [ 3.54015362]
#  [-8.00369517]
#  [-9.42973046]
#  [36.28532082]]

# %%
plt.plot(range(len(Y_pred)),Y_test,label='true value')
plt.plot(range(len(Y_pred)),Y_pred,label = 'predicted value')
plt.ylabel('CO2 concentration')
plt.title('Our prediction')
plt.legend()
plt.show()

# %% [markdown]
# # Test using Sklearn Library

# %%
# sikitlearn library comparement
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_i, Y_i, test_size=0.2,random_state=1)

ridge = linear_model.Ridge(alpha=0.0001,normalize = True).fit(X_train, Y_train)
Y_pred = ridge.predict(X_test)
score_ridge = ridge.score(X_test, Y_test)
mse_ridge = mean_squared_error(Y_test, Y_pred)
print("Final Result: Ridge R2:{0:.3f}, MSE:{1:.3f}, RMSE:{2:.10f}".format(score_ridge, mse_ridge, np.sqrt(mse_ridge)))
# Out:
# Final Result: Ridge R2:0.999, MSE:0.473, RMSE:0.6878278444

# %%
# comparison true value and predicted value

count = np.array(range(Y_test.shape[0]))
plt.title('Sklearn prediction')
plt.plot(count, Y_test, label='true value')
plt.ylabel('CO2 concentration')
plt.plot(count, Y_pred, label='predicted value')
plt.legend()
plt.show()

# %% [markdown]
# # Checking Alpha dependence

# %%
alpha_list = np.linspace(0,10,100)


mse_l = []
for a in alpha_list:
    beta_ridge, beta_0 = Ridge.solve(X_norm, Y_train,a)
    
    #test data
    
    test_norm = (X_test-X_mean)/X_std
    Y_pred = np.matmul(test_norm, beta_ridge)+beta_0

    mse = mean_squared_error(Y_test, Y_pred)

    print("Alpha : ",a,"Result MSE, RMSE ",mse, np.sqrt(mse))
    mse_l.append(np.sqrt(mse))
# Out:
# Alpha :  0.0 Result MSE, RMSE  0.4119166106804497 0.6418073002704547
# Alpha :  0.10101010101010101 Result MSE, RMSE  0.5417264465622206 0.7360206835152261
# Alpha :  0.20202020202020202 Result MSE, RMSE  0.6749800046918837 0.8215716674106305
# Alpha :  0.30303030303030304 Result MSE, RMSE  0.784309518930146 0.8856125105993851
# Alpha :  0.40404040404040403 Result MSE, RMSE  0.8767944234444293 0.9363730151197381
# Alpha :  0.5050505050505051 Result MSE, RMSE  0.9576150245290882 0.9785780625627616
# Alpha :  0.6060606060606061 Result MSE, RMSE  1.0300790565338613 1.0149281041206129
# Alpha :  0.7070707070707071 Result MSE, RMSE  1.0963590901099072 1.0470716738169872
# Alpha :  0.8080808080808081 Result MSE, RMSE  1.1579354605547432 1.07607409621956
# Alpha :  0.9090909090909091 Result MSE, RMSE  1.2158483499757402 1.1026551364664023
# Alpha :  1.0101010101010102 Result MSE, RMSE  1.2708469120825705 1.1273184608097973
# Alpha :  1.1111111111111112 Result MSE, RMSE  1.3234815996581137 1.1504267032967002
# Alpha :  1.2121212121212122 Result MSE, RMSE  1.3741636404445752 1.1722472607963625
# Alpha :  1.3131313131313131 Result MSE, RMSE  1.423204626843471 1.1929814025555767
# Alpha :  1.4141414141414141 Result MSE, RMSE  1.470843588565311 1.2127834054625382
# Alpha :  1.5151515151515151 Result MSE, RMSE  1.5172659249452014 1.2317734876775037
# Alpha :  1.6161616161616161 Result MSE, RMSE  1.5626168964614344 1.2500467577100605
# Alpha :  1.7171717171717171 Result MSE, RMSE  1.607011394716979 1.2676795315524263
# Alpha :  1.8181818181818181 Result MSE, RMSE  1.6505411160711587 1.2847338697454656
# Alpha :  1.9191919191919191 Result MSE, RMSE  1.6932798927563952 1.3012608857398256
# Alpha :  8.98989898989899 Result MSE, RMSE  3.6770362644017527 1.9175599767417322
# Alpha :  9.09090909090909 Result MSE, RMSE  3.696064155758082 1.9225150599561196
# Alpha :  9.191919191919192 Result MSE, RMSE  3.7149167165893324 1.9274119218758954
# Alpha :  9.292929292929292 Result MSE, RMSE  3.733596418183958 1.9322516446322302
# Alpha :  9.393939393939394 Result MSE, RMSE  3.75210568696705 1.937035282840003
# Alpha :  9.494949494949495 Result MSE, RMSE  3.7704469053954557 1.9417638644787516
# Alpha :  9.595959595959595 Result MSE, RMSE  3.7886224128357178 1.9464383917390546
# Alpha :  9.696969696969697 Result MSE, RMSE  3.80663450643047 1.9510598418373717
# Alpha :  9.797979797979798 Result MSE, RMSE  3.824485441947943 1.9556291677994433
# Alpha :  9.8989898989899 Result MSE, RMSE  3.842177434620311 1.9601472992151152
# Alpha :  10.0 Result MSE, RMSE  3.859712659964294 1.9646151429642127

# %%
plt.plot(alpha_list.tolist(),mse_l)
plt.xlabel('$\lambda$')
plt.ylabel('RMSE')
plt.title('$\lambda$ dependency')
# Out:
# Text(0.5, 1.0, '$\\lambda$ dependency')

# %% [markdown]
# # cross validation

# %%
import numpy as np 
from sklearn.model_selection import KFold 
kf = KFold(n_splits=7) 
Train = []
Test = []
for train, test in kf.split(X_i): 
    print("%s %s" % (len(train), len(test)))
    Train.append(train)
    Test.append(test)
# Out:
# 585 98
# 585 98
# 585 98
# 585 98
# 586 97
# 586 97
# 586 97

# %%
from sklearn.model_selection import ShuffleSplit
ss = ShuffleSplit(n_splits=100, test_size=0.25, random_state=0) 
Train = []
Test = []
for train_index, test_index in ss.split(X_i): 
    Train.append(train_index)
    Test.append(test_index)
print("%s %s" % (len(train_index), len(test_index)))
# Out:
# 512 171

# %%
from sklearn.metrics import mean_squared_error
mse_l = []
for i in range(len(Train)):
    #test data
    train = Train[i]
    test = Test[i]
    
    X_norm = stats.zscore(X_i[train],axis=0)
    X_std = np.std(X_i[train],axis=0)
    X_mean = np.mean(X_i[train],axis=0)

    beta_ridge, beta_0 = Ridge.solve(X_norm, Y_i[train],0.1)
    #test data
    
    # test
    test_norm = (X_i[test]-X_mean)/X_std
    Y_pred = np.matmul(test_norm, beta_ridge)+beta_0

    mse = mean_squared_error(Y_i[test], Y_pred)
    plt.scatter(i,np.sqrt(mse))
    mse_l.append(np.sqrt(mse))
plt.title('Root Mean Squared Error for each set')
plt.ylabel('RMSE')
plt.axhline(y=0.7822, color='r', linestyle='-')
plt.text(106,0.79,'Mean = 0.78224')
plt.text(106,0.765,'Std = 0.0337')
plt.ylim([0.6,1])
# Out:
# (0.6, 1.0)

# %%
print("Mean mse is ", np.mean(mse_l))
print("Mean mse is ", np.std(mse_l))
# Out:
# Mean mse is  0.782246917490864
# Mean mse is  0.03371675962961953

# %% [markdown]
# # cross validation x alpha dependence

# %%
def cross_validation(c_x,c_y,alpha):
    ss = ShuffleSplit(n_splits=100, test_size=0.3, random_state=0) 
    Train = []
    Test = []
    for train_index, test_index in ss.split(c_x): 
        Train.append(train_index)
        Test.append(test_index)
    
    
    mse_l = []
    for i in range(len(Train)):
    #test data
        train = Train[i]
        test = Test[i]
    
        X_norm = stats.zscore(c_x[train],axis=0)
        X_std = np.std(c_x[train],axis=0)
        X_mean = np.mean(c_x[train],axis=0)

        beta_ridge, beta_0 = Ridge.solve(X_norm, c_y[train],alpha)
        #test data
        
        # test
        test_norm = (c_x[test]-X_mean)/X_std
        Y_pred = np.matmul(test_norm, beta_ridge)+beta_0
        
        mse = mean_squared_error(c_y[test], Y_pred)
        
        mse_l.append(np.sqrt(mse))
    return np.mean(mse_l)

# %%
alpha_list = np.linspace(0,2,30)


mean_mse_l = []
for a in alpha_list:
    mean_mse_l.append(cross_validation(X_i,Y_i,a))

# %%
plt.plot(alpha_list,mean_mse_l)
plt.title('Root Mean Squared Error for each labmda')
plt.ylabel('mean RMSE from cross validation')
plt.xlabel('$\lambda$')
plt.show()

# %% [markdown]
# # Use past 500 months data to predict the future

# %%
X_train = X_i[:500, :]
X_test = X_i[500:, :]
Y_train = Y_i[:500]
Y_test = Y_i[500:]

# %%
X_norm = stats.zscore(X_train,axis=0)
X_std = np.std(X_train,axis=0)
X_mean = np.mean(X_train,axis=0)

# %%
beta_ridge, beta_0 = Ridge.solve(X_norm, Y_train,0.1)

# %%
print("beta_ridge:")
print(beta_ridge)
# Out:
# beta_ridge:
# [[  4.66557668]
#  [ -5.58170511]
#  [  2.52001149]
#  [  3.43729798]
#  [ -4.423848  ]
#  [-10.35685457]
#  [ 26.4510888 ]]

# %%
# test
test_norm = (X_test-X_mean)/X_std
Y_pred = np.matmul(test_norm, beta_ridge)+beta_0

mse = mean_squared_error(Y_test, Y_pred)
print("Result MSE, RMSE ",mse, np.sqrt(mse))
# Out:
# Result MSE, RMSE  0.6469131242563195 0.8043090974596269

# %%
count = np.array(range(500,500+Y_pred.shape[0]))
plt.plot(count, Y_pred, label='predicted value')
plt.xlabel('count')
plt.ylabel('CO2 concentration')
plt.plot(count, Y_test, label='true value')
plt.title('Using past 500 months data to predict the future')
plt.legend()
plt.show()

# %% [markdown]
# # Varying window size

# %%
from sklearn.model_selection import train_test_split
window_size = list(range(2, 100, 1))
mse = []
rmse = []

for a in window_size:
    X,Y = window_make.dowlist(co2,a)
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=1)

    # training
    X_norm = stats.zscore(X_train,axis=0)
    X_std = np.std(X_train,axis=0)
    X_mean = np.mean(X_train,axis=0)
    
    beta_ridge, beta_0 = Ridge.solve(X_norm, Y_train,0.1)
    
    
    test_norm = (X_test-X_mean)/X_std
    
    Y_pred = np.matmul(test_norm, beta_ridge)+beta_0
    
    error = mean_squared_error(Y_test, Y_pred)
    mse.append(error)
    rmse.append(np.sqrt(error))

# %%
plt.plot(window_size, rmse)
plt.xlabel('Window size')
plt.ylabel('RMSE')
plt.savefig('RMSE_depending_on_window_size3.png', dpi=300)
plt.axvline(x = 13,color='r')
plt.title('RMSE according to the window size')
plt.text(17,0.7,'Window size =13')
plt.show()
